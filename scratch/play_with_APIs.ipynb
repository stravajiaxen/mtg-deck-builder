# %%
import requests
import pprint
from builder.lists import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 import requests
#       2 import pprint
# ----> 3 from builder.lists import *
#
# File ~\Documents\coding\mtg_deck_builder\builder\lists.py:3
#       1 from urllib.parse import urljoin
#       2 import requests
# ----> 3 import pandas as pd
#       4 import os
#       5 import sys
#
# ModuleNotFoundError: No module named 'pandas'

# %%
my_cards

# %%
url = "https://json.edhrec.com/pages/decks/zaxara-the-exemplary.json"
response = requests.get(url)
response.json()
# Out:
# {'container': {'breadcrumb': [{'#': 'Decklists'},
#    {'/decks/zaxara-the-exemplary': 'Zaxara, the Exemplary'}],
#   'description': 'Decks with Zaxara, the Exemplary',
#   'json_dict': {'card': {'inclusion': 7647,
#     'num_decks': 7647,
#     'potential_decks': 2390220,
#     'aetherhub_uri': 'Zaxara%2C%20the%20Exemplary',
#     'archidekt_uri': '%22Zaxara%2C%20the%20Exemplary%22',
#     'color_identity': ['B', 'G', 'U'],
#     'cmc': 4.0,
#     'deckstats_uri': 'https://deckstats.net/decks/search/?search_cards[]=Zaxara%2C%20the%20Exemplary&search_format=10',
#     'image_uris': [{'small': 'https://cards.scryfall.io/small/front/6/d/6dc390da-75f8-490a-a724-c12d21cfe578.jpg?1673305726',
#       'normal': 'https://cards.scryfall.io/normal/front/6/d/6dc390da-75f8-490a-a724-c12d21cfe578.jpg?1673305726',
#       'large': 'https://cards.scryfall.io/large/front/6/d/6dc390da-75f8-490a-a724-c12d21cfe578.jpg?1673305726',
# ...

# %%
base = "https://edhrec.com/deckpreview/"
links = []
for item in response.json()["table"]:
    links.append(base+item["urlhash"])
    
print(links[0])
# Out:
# https://edhrec.com/deckpreview/3aYPcFC1l-c8CRJ6a65i3Q
